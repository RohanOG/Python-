# %%
import mysql.connector

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password=""
)

mycursor = mydb.cursor()

mycursor.execute("SHOW DATABASES")

for x in mycursor:
  print(x)
# Out:
# ('information_schema',)
# ('mysql',)
# ('performance_schema',)
# ('phpmyadmin',)
# ('satan',)
# ('test',)

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="",
  database="satan"
)

mycursor = mydb.cursor()

mycursor.execute("CREATE TABLE teacher (name VARCHAR(255), address VARCHAR(255))")

# %%
import matplotlib.pyplot as plt
import pandas as pd 
class Test:
    def main ():
        pip =pd.read_csv('amsterdam_weekdays.csv')
        pip.plot()
        plt.show
Test.main()

# %%
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)

plt.show()

# %%
import sys
import matplotlib
matplotlib.use('Agg')

import matplotlib.pyplot as plt
import numpy as np

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)

plt.show()

#Two  lines to make our compiler able to draw:
plt.savefig(sys.stdout.buffer)
sys.stdout.flush()
# Out:
# C:\Users\toroh\AppData\Local\Temp\ipykernel_19048\4174720825.py:44: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 47
#      44 plt.show()
#      46 #Two  lines to make our compiler able to draw:
# ---> 47 plt.savefig(sys.stdout.buffer)
#      48 sys.stdout.flush()
#
# AttributeError: 'OutStream' object has no attribute 'buffer'

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 4, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 4, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 4, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 4, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 4, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 4, 6)
plt.plot(x,y)

plt.show()
# Out:
# C:\Users\toroh\AppData\Local\Temp\ipykernel_19048\3619148597.py:40: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(3, 4, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(3, 4, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(3, 4, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(3, 4, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(3, 4, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(3, 4, 6)
plt.plot(x,y)

x = np.array([0, 12, 22, 32])
y = np.array([10, 20, 30, 40])

plt.subplot(3, 4, 7)
plt.plot(x,y)

x = np.array([0, 14, 24, 34])
y = np.array([10, 20, 30, 40])

plt.subplot(3, 4, 8)
plt.plot(x,y)

x = np.array([0, 16, 26, 36])
y = np.array([10, 20, 30, 40])

plt.subplot(3, 4, 9)
plt.plot(x,y)

x = np.array([0, 16, 26, 36])
y = np.array([10, 20, 30, 40])

plt.subplot(3, 4, 10)
plt.plot(x,y)

x = np.array([0, 16, 26, 36])
y = np.array([10, 20, 30, 40])

plt.subplot(3, 4, 11)
plt.plot(x,y)

y = np.array([0, 16, 26, 36])


plt.subplot(3, 4, 12)
plt.pie(y)








plt.show()

# %%
]]
]

# %%
import  mysql.connector

mydb=mysql.connector.connect(
  host="localhost",
  user="root",
  password=""
)

mycursor = mydb.cursor()

mycursor.execute("CREATE DATABASE Rohan")

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password=""
)

mycursor = mydb.cursor()

mycursor.execute("SHOW DATABASES")

for x in mycursor:
  print(x)
# Out:
# ('information_schema',)
# ('mysql',)
# ('performance_schema',)
# ('phpmyadmin',)
# ('rohan',)
# ('satan',)
# ('test',)

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="",
  database="rohan"
)

mycursor = mydb.cursor()

mycursor.execute("CREATE TABLE customers (name VARCHAR(255), address VARCHAR(255), gender VARCHAR(255), roll_no VARCHAR(255))")
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[50], line 12
#       3 mydb = mysql.connector.connect(
#       4   host="localhost",
#       5   user="root",
#       6   password="",
#       7   database="rohan"
#       8 )
#      10 mycursor = mydb.cursor()
# ---> 12 mycursor.execute("CREATE TABLE customers (name VARCHAR(255), address VARCHAR(255), gender VARCHAR(255), roll_no VARCHAR(255))")
#
# File c:\Users\toroh\AppData\Local\Programs\Python\Python311\Lib\site-packages\mysql\connector\cursor.py:551, in MySQLCursor.execute(self, operation, params, multi)
#     549 else:
#     550     try:
# --> 551         self._handle_result(self._connection.cmd_query(stmt))
#     552     except errors.InterfaceError:
#     553         if self._connection._have_next_result:  # pylint: disable=W0212
#
# ...

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="",
  database="rohan"
)

mycursor = mydb.cursor()

mycursor.execute("CREATE TABLE info (name VARCHAR(255), address VARCHAR(255), gender VARCHAR(255), roll_no VARCHAR(255), age VARCHAR(255))")
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[52], line 12
#       3 mydb = mysql.connector.connect(
#       4   host="localhost",
#       5   user="root",
#       6   password="",
#       7   database="rohan"
#       8 )
#      10 mycursor = mydb.cursor()
# ---> 12 mycursor.execute("CREATE TABLE info (name VARCHAR(255), address VARCHAR(255), gender VARCHAR(255), roll_no VARCHAR(255), age VARCHAR(255))")
#
# File c:\Users\toroh\AppData\Local\Programs\Python\Python311\Lib\site-packages\mysql\connector\cursor.py:551, in MySQLCursor.execute(self, operation, params, multi)
#     549 else:
#     550     try:
# --> 551         self._handle_result(self._connection.cmd_query(stmt))
#     552     except errors.InterfaceError:
#     553         if self._connection._have_next_result:  # pylint: disable=W0212
#
# ...

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="",
  database="rohan"
)

mycursor = mydb.cursor()

mycursor.execute("CREATE TABLE customers (name VARCHAR(255), address VARCHAR(255), gender VARCHAR(255), roll_no VARCHAR(255),age VARCHAR(255)")
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[53], line 12
#       3 mydb = mysql.connector.connect(
#       4   host="localhost",
#       5   user="root",
#       6   password="",
#       7   database="rohan"
#       8 )
#      10 mycursor = mydb.cursor()
# ---> 12 mycursor.execute("CREATE TABLE customers (name VARCHAR(255), address VARCHAR(255), gender VARCHAR(255), roll_no VARCHAR(255),age VARCHAR(255)")
#
# File c:\Users\toroh\AppData\Local\Programs\Python\Python311\Lib\site-packages\mysql\connector\cursor.py:551, in MySQLCursor.execute(self, operation, params, multi)
#     549 else:
#     550     try:
# --> 551         self._handle_result(self._connection.cmd_query(stmt))
#     552     except errors.InterfaceError:
#     553         if self._connection._have_next_result:  # pylint: disable=W0212
#
# ...

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="",
  database="rohan"
)

mycursor = mydb.cursor()

mycursor.execute("CREATE TABLE info (name VARCHAR(255), address VARCHAR(255), gender VARCHAR(255), roll_no VARCHAR(255), age VARCHAR(255))")

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="",
  database="rohan"
)

mycursor = mydb.cursor()

sql = "INSERT INTO info(name, address, ganeder,roll_no,age) VALUES (%s, %s, %s, %s, %%)"
val = ("BIshal", "Siliguri",)
mycursor.execute(sql, val)

mydb.commit()

print(mycursor.rowcount, "record inserted.")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File c:\Users\toroh\AppData\Local\Programs\Python\Python311\Lib\site-packages\mysql\connector\cursor.py:75, in _ParamSubstitutor.__call__(self, matchobj)
#      74 try:
# ---> 75     return bytes(self.params[index])
#      76 except IndexError:
#
# IndexError: tuple index out of range
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[55], line 14
#      12 sql = "INSERT INTO info(name, address, ganeder,roll_no,age) VALUES (%s, %s, %s, %s, %%)"
#      13 val = ("BIshal", "Siliguri",)
# ---> 14 mycursor.execute(sql, val)
#      16 mydb.commit()
#      18 print(mycursor.rowcount, "record inserted.")
#
# ...

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="",
  database="rohan"
)

mycursor = mydb.cursor()

sql = "INSERT INTO info(name, address, ganeder,roll_no,age) VALUES (%s, %s, %s, %s, %%)"
val = ("BIshal", "Siliguri","female", "10", "19")
mycursor.execute(sql, val)

mydb.commit()

print(mycursor.rowcount, "record inserted.")
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[56], line 14
#      12 sql = "INSERT INTO info(name, address, ganeder,roll_no,age) VALUES (%s, %s, %s, %s, %%)"
#      13 val = ("BIshal", "Siliguri","female", "10", "19")
# ---> 14 mycursor.execute(sql, val)
#      16 mydb.commit()
#      18 print(mycursor.rowcount, "record inserted.")
#
# File c:\Users\toroh\AppData\Local\Programs\Python\Python311\Lib\site-packages\mysql\connector\cursor.py:542, in MySQLCursor.execute(self, operation, params, multi)
#     540         stmt = RE_PY_PARAM.sub(psub, stmt)
#     541         if psub.remaining != 0:
# --> 542             raise errors.ProgrammingError(
#     543                 "Not all parameters were used in the SQL statement")
#     545 self._executed = stmt
#     546 if multi:
#
# ProgrammingError: Not all parameters were used in the SQL statement

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="",
  database="rohan"
)

mycursor = mydb.cursor()

mycursor.execute("CREATE TABLE info (name VARCHAR(255), address VARCHAR(255), gender VARCHAR(255), roll_no VARCHAR(255), age VARCHAR(255))")

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="",
  database="rohan"
)

mycursor = mydb.cursor()

sql = "INSERT INTO info(name, address, gender,roll_no,age) VALUES (%s, %s, %s, %s, %s)"
val1 = str(input("ENTER THE NAME->"))
val2 = str(input("ENTER THE address->"))
val3 = str(input("ENTER THE gender->"))
val4 = str(input("ENTER THE roll_no->"))
val5 = str(input("ENTER THE age->"))
val=(val1,val2,val3,val4,val5)
mycursor.execute(sql, val)

mydb.commit()

print(mycursor.rowcount, "record inserted.")
# Out:
# 1 record inserted.

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="",
  database="rohan"
)

mycursor = mydb.cursor()

mycursor.execute("SELECT * FROM info")

myresult = mycursor.fetchall()

for x in myresult:
  print(x)
# Out:
# ('BIshal', 'Siliguri', 'female', '10', '19')
# ('', 'SAIF', '', 'female', '20')
# ('rohan', 'delhi', 'male', '5544', "'7")

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="",
  database="rohan"
)

mycursor = mydb.cursor()

sql = "DELETE FROM info WHERE name = 'Bishal'"

mycursor.execute(sql)

mydb.commit()

print(mycursor.rowcount, "record(s) deleted")
# Out:
# 1 record(s) deleted

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="",
  database="rohan"
)

mycursor = mydb.cursor()

sql = "DELETE FROM info WHERE address = %s"
x=int(input("Enter a address to delete ->"))
val=(x)

mycursor.execute(sql)

mydb.commit()

print(mycursor.rowcount, "record(s) deleted")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 13
#      10 mycursor = mydb.cursor()
#      12 sql = "DELETE FROM info WHERE address = %s"
# ---> 13 x=int(input("Enter a address to delete ->"))
#      14 val=(x)
#      16 mycursor.execute(sql)
#
# ValueError: invalid literal for int() with base 10: 'SAIF'

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="",
  database="rohan"
)

mycursor = mydb.cursor()

sql = "INSERT INTO info(name, address, gender,roll_no,age) VALUES (%s, %s, %s, %s, %s)"
val1 = str(input("ENTER THE NAME->"))
val2 = str(input("ENTER THE address->"))
val3 = str(input("ENTER THE gender->"))
val4 = str(input("ENTER THE roll_no->"))
val5 = str(input("ENTER THE age->"))
val=(val1,val2,val3,val4,val5)
mycursor.execute(sql, val)

mydb.commit()

print(mycursor.rowcount, "record inserted.")
# Out:
# 1 record inserted.

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="",
  database="rohan"
)

mycursor = mydb.cursor()

sql = "DELETE FROM info WHERE gender = %s"
x=str(input("Enter a value to delete ->"))
val=(x,)

mycursor.execute(sql,val)

mydb.commit()

print(mycursor.rowcount, "record(s) deleted")
# Out:
# 2 record(s) deleted

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="",
  database="rohan"
)

mycursor = mydb.cursor()

sql = "UPDATE info SET address = 'siliguri' WHERE  name = 'popa'"

mycursor.execute(sql)

mydb.commit()

print(mycursor.rowcount, "record(s) affected")
# Out:
# 1 record(s) affected

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="",
  database="rohan"
)

mycursor = mydb.cursor()

sql = "DELETE FROM info WHERE age = %s"
x=int(input("Enter a value to delete ->"))
val=(x,)

mycursor.execute(sql,val)

mydb.commit()

print(mycursor.rowcount, "record(s) deleted")
# Out:
# 1 record(s) deleted

# %%
pip list
# Out:
# Package           Version
# ----------------- --------
# asttokens         2.2.1
# backcall          0.2.0
# colorama          0.4.6
# comm              0.1.2
# contourpy         1.0.7
# cycler            0.11.0
# debugpy           1.6.6
# decorator         5.1.1
# executing         1.2.0
# fonttools         4.38.0
# ipykernel         6.21.2
# ipython           8.10.0
# jedi              0.18.2
# jupyter_client    8.0.3
# jupyter_core      5.2.0
# kiwisolver        1.4.4
# matplotlib        3.7.0
# matplotlib-inline 0.1.6
# mysql             0.0.3
# mysql-connector   2.2.9
# mysqlclient       2.1.1
# nest-asyncio      1.5.6
# numpy             1.24.2
# packaging         23.0
# pandas            1.5.3
# parso             0.8.3
# pickleshare       0.7.5
# Pillow            9.4.0
# pip               23.0.1
# platformdirs      3.0.0
# prompt-toolkit    3.0.37
# psutil            5.9.4
# pure-eval         0.2.2
# Pygments          2.14.0
# pyparsing         3.0.9
# ...

# %%
import math
a=12.345465
c=math.ceil(a)
print(c)
b=math.floor(a)
print (b)
z=121
x=math.sqrt(z)
print(x)
# Out:
# 13
# 12
# 11.0

# %%
import numpy as np
class ArraySearch:
     def ArrSearch():
         arr=[]
         n=int(input("Enetr the no. of array elements->"))
         for x in range (n):
             arr.append(int(input()))
         arr=np.array(arr)
         print("original array ->",arr)
         print(n)

# %%
a=int(input("Number of elements in the array:-"))
n=list(map(int, input("elements of array:-").strip().split()))
print(n)
z=min(n)
y=max(n)
print (z)
print(y)
# Out:
# [32, 45, 3, 4, 66, 78]
# 3
# 78

# %%
employees={}
n=int(input("Enter the number of datas->"))
for i in range(n):
    name =input("Enter employee's name:")
    salary =input("Enter emlpoyee's salary:")

    employees[name]=salary
print(salary)
print(type(employees))
print("\n")
for x,y in employees.items():
    print(x,y)
# Out:
# 67567
# <class 'dict'>
#
#
# rohan 34534
# bishal 67567

# %%
child1 = {
  "name" : "Emil",
  "year" : 2004
}
child2 = {
  "name" : "Tobias",
  "year" : 2007
}
child3 = {
  "name" : "Linus",
  "year" : 2011
}

myfamily = {
  "child1" : child1,
  "child2" : child2,
  "child3" : child3
}

# %%
myfamily = {
  "child1" : {
    "name" : "Emil",
    "year" : 2004
  },
  "child2" : {
    "name" : "Tobias",
    "year" : 2007
  },
  "child3" : {
    "name" : "Linus",
    "year" : 2011
  }
}

for x, y in myfamily.items():
    print(x,y)
# Out:
# child1 {'name': 'Emil', 'year': 2004}
# child2 {'name': 'Tobias', 'year': 2007}
# child3 {'name': 'Linus', 'year': 2011}

# %%
import json
 
# Data to be written
dictionary = {
    "name": "sathiyajith",
    "rollno": 56,
    "cgpa": 8.6,
    "phonenumber": "9976770500"
}
 
# Serializing json
json_object = json.dumps(dictionary, indent=4)
 
# Writing to sample.json
with open("sample.json", "w") as outfile:
    outfile.write(json_object)

# %%
import json
 
# Opening JSON file
with open('sample.json', 'r') as openfile:
 
    # Reading from json file
    json_object = json.load(openfile)
 
print(json_object)
print(type(json_object))
# Out:
# {'name': 'sathiyajith', 'rollno': 56, 'cgpa': 8.6, 'phonenumber': '9976770500'}
# <class 'dict'>

# %%
import json
employees ={}
n=int(input("Enter the number of datas->"))
for i in range(n):
    name =input("Enter employee's name:")
    salary =input("Enter emlpoyee's salary:")
    blood_group = str(input("Enter blood group"))
    employee_id=input("Enter employee id") 

    employees[name]=salary
    employees[employee_id]=blood_group

print(employees)
print(type(employees))
print("\n")
for x,y in employees.items():
    print(x,y)

# %%
import matplotlib.pyplot as plt
import pandas as pd 

        pip =pd.read_csv('usa_country_wise.csv')
        pip.plot()
        plt.show
Test.main()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 8
#       6         pip.plot()
#       7         plt.show
# ----> 8 Test.main()
#
# Cell In[17], line 5, in Test.main()
#       4 def main ():
# ----> 5     pip =pd.read_csv('usa_country_wise.csv')
#       6     pip.plot()
#       7     plt.show
#
# File c:\Users\toroh\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\toroh\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd 
class Test:
    def main ():
        pip =pd.read_csv('usa_county_wise.csv')
        pip.plot()
        plt.show
        x=pip.info()
        y=pip.head()
        z=pip.tail()
        print(x,y,z)
Test.main()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 627920 entries, 0 to 627919
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   UID             627920 non-null  int64
#  1   iso2            627920 non-null  object
#  2   iso3            627920 non-null  object
#  3   code3           627920 non-null  int64
#  4   FIPS            626040 non-null  float64
#  5   Admin2          626792 non-null  object
#  6   Province_State  627920 non-null  object
#  7   Country_Region  627920 non-null  object
#  8   Lat             627920 non-null  float64
#  9   Long_           627920 non-null  float64
#  10  Combined_Key    627920 non-null  object
#  11  Date            627920 non-null  object
#  12  Confirmed       627920 non-null  int64
#  13  Deaths          627920 non-null  int64
# dtypes: float64(3), int64(4), object(7)
# memory usage: 67.1+ MB
# ...

# %%
import pandas as pd
df=pd.read_csv('day_wise.csv')
df.fillna(110,inplace=True)

# %%
n=int(input("Enter a number"))
for i in range (1,11):
    z=n*i
    print(z)
# Out:
# 11
# 22
# 33
# 44
# 55
# 66
# 77
# 88
# 99
# 110

# %%
cars = ["Ford", "Volvo", "BMW"]

x = cars[0]

print(x)
# Out:
# Ford

# %%
cars = ["Ford", "Volvo", "BMW"]

x = len(cars)

print(x)
# Out:
# 3

# %%
class MyClass:
  x = 5

print(MyClass)
# Out:
# <class '__main__.MyClass'>

# %%
class MyClass:
  x = 5

p1 = MyClass()
print(p1.x)
# Out:
# 5

# %%
class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

p1 = Person("John", 36)

print(p1.name)
print(p1.age)
# Out:
# John
# 36

# %%
class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

p1 = Person("John", 36)

print(p1)

# %%
import json

# some JSON:
x = '{ "name":"John", "age":30, "city":"New York"}'

# parse x:
y = json.loads(x)

# the result is a Python dictionary:
print(y["age"])
# Out:
# 30

# %%
import json

# a Python object (dict):
x = {
  "name": "John",
  "age": 30,
  "city": "New York"
}

# convert into JSON:
y = json.dumps(x)

# the result is a JSON string:
print(y)
# Out:
# {"name": "John", "age": 30, "city": "New York"}

# %%
import json

x = {
  "name": "John",
  "age": 30,
  "married": True,
  "divorced": False,
  "children": ("Ann","Billy"),
  "pets": None,
  "cars": [
    {"model": "BMW 230", "mpg": 27.5},
    {"model": "Ford Edge", "mpg": 24.1}
  ]
}

# convert into JSON:
y = json.dumps(x)

# the result is a JSON string:
print(y)
# Out:
# {"name": "John", "age": 30, "married": true, "divorced": false, "children": ["Ann", "Billy"], "pets": null, "cars": [{"model": "BMW 230", "mpg": 27.5}, {"model": "Ford Edge", "mpg": 24.1}]}

# %%
username = input("Enter username:")
print("Username is: " + username)
# Out:
# Username is: ROHAN

# %%
import numpy as np

arr = np.array([1, 2, 3, 4, 5])

print(arr)

print(type(arr))
# Out:
# [1 2 3 4 5]
# <class 'numpy.ndarray'>

# %%
import numpy as np

arr = np.array([1, 2, 3, 4, 5])

print(arr)

print(type(arr))
# Out:
# [1 2 3 4 5]
# <class 'numpy.ndarray'>

# %%
import numpy as np

a = np.array(42)
b = np.array([1, 2, 3, 4, 5])
c = np.array([[1, 2, 3], [4, 5, 6]])
d = np.array([[[1, 2, 3], [4, 5, 6]], [[1, 2, 3], [4, 5, 6]]])

print(a.ndim)
print(b.ndim)
print(c.ndim)
print(d.ndim)
# Out:
# 0
# 1
# 2
# 3

# %%
import numpy as np

arr1 = np.array([1, 2, 3])

arr2 = np.array([4, 5, 6])

arr = np.concatenate((arr1, arr2))

print(arr)
# Out:
# [1 2 3 4 5 6]

# %%
import numpy as np

arr1 = np.array([1, 2, 3])

arr2 = np.array([4, 5, 6])

arr = np.stack((arr1, arr2), axis=1)

print(arr)
# Out:
# [[1 4]
#  [2 5]
#  [3 6]]

# %%
from numpy import random

x = random.choice([3, 5, 7, 9], p=[0.1, 0.3, 0.6, 0.0], size=(3, 5))

print(x)
# Out:
# [[7 7 7 5 5]
#  [3 5 5 7 7]
#  [5 7 5 5 7]]

# %%
from numpy import random

x = random.choice([3, 5, 7, 9], p=[0.1, 0.3, 0.6, 0.0], size=(3, 5))

print(x)
# Out:
# [[5 7 7 5 7]
#  [5 7 7 7 7]
#  [7 7 7 7 5]]

# %%
import matplotlib


import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints)
plt.show()

# plt.savefig(sys.stdout.buffer)
# sys.stdout.flush()
# Out:
# C:\Users\toroh\AppData\Local\Temp\ipykernel_1416\1100468126.py:11: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %%
import matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10, 5, 7])

plt.plot(ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])

plt.pie(y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels, startangle = 90)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
plt.show()

# %%
import numpy as np

x = np.random.normal(170, 10, 250)

print(x)
# Out:
# [173.91632069 166.30164576 177.59137109 160.89543141 173.83390055
#  168.12357166 148.09209772 173.92879563 174.55714873 181.27654633
#  163.26085449 182.00389409 167.23326094 162.84898444 167.65816512
#  166.70225561 163.41681728 173.34887747 153.31454797 154.91268844
#  165.17882395 164.68806388 179.61153914 162.39855716 165.06407142
#  171.27297255 172.99389174 171.00291639 163.19484796 164.11386735
#  174.82540723 172.66681166 164.54290054 174.76943351 152.50235721
#  157.56944614 176.25742372 168.26845677 168.46433109 179.26870281
#  171.62814664 165.28907868 174.49837793 189.18595779 182.51548989
#  176.87562314 171.56861831 165.07645203 180.40097077 173.22063843
#  157.5893377  189.96184027 182.81020927 179.65627053 167.88732348
#  158.27373535 163.34861442 192.25099303 183.89996864 173.06741414
#  173.49433863 177.20511112 185.91348787 173.47828747 167.69398311
#  186.5732104  152.51669515 161.69246971 177.21548362 156.85250607
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()

# %%
import pandas as pd

df = pd.read_csv('usa_county_wise.csv')

print(df.to_string())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 5
#       1 import pandas as pd
#       3 df = pd.read_csv('usa_county_wise.csv')
# ----> 5 print(df.to_string())
#
# File c:\Users\toroh\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1245, in DataFrame.to_string(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, max_rows, max_cols, show_dimensions, decimal, line_width, min_rows, max_colwidth, encoding)
#    1226 with option_context("display.max_colwidth", max_colwidth):
#    1227     formatter = fmt.DataFrameFormatter(
#    1228         self,
#    1229         columns=columns,
#    (...)
#    1243         decimal=decimal,
#    1244     )
# -> 1245     return fmt.DataFrameRenderer(formatter).to_string(
#    1246         buf=buf,
#    1247         encoding=encoding,
# ...

# %%
import pandas as pd

# %%
import pandas as pd

df = pd.read_csv('usa_county_wise.csv')

print(df)
# Out:
#              UID iso2 iso3  code3     FIPS          Admin2  \
# 0             16   AS  ASM     16     60.0             NaN
# 1            316   GU  GUM    316     66.0             NaN
# 2            580   MP  MNP    580     69.0             NaN
# 3       63072001   PR  PRI    630  72001.0        Adjuntas
# 4       63072003   PR  PRI    630  72003.0          Aguada
# ...          ...  ...  ...    ...      ...             ...
# 627915  84070016   US  USA    840      NaN    Central Utah
# 627916  84070017   US  USA    840      NaN  Southeast Utah
# 627917  84070018   US  USA    840      NaN  Southwest Utah
# 627918  84070019   US  USA    840      NaN       TriCounty
# 627919  84070020   US  USA    840      NaN    Weber-Morgan
#
#                   Province_State Country_Region        Lat       Long_  \
# 0                 American Samoa             US -14.271000 -170.132000
# 1                           Guam             US  13.444300  144.793700
# ...

# %%
import pandas as pd

data = {
  "Duration":{
    "0":60,
    "1":60,
    "2":60,
    "3":45,
    "4":45,
    "5":60
  },
  "Pulse":{
    "0":110,
    "1":117,
    "2":103,
    "3":109,
    "4":117,
    "5":102
  },
  "Maxpulse":{
    "0":130,
    "1":145,
    "2":135,
    "3":175,
    "4":148,
    "5":127
  },
  "Calories":{
    "0":409.1,
    "1":479.0,
    "2":340.0,
    "3":282.4,
    "4":406.0,
    "5":300.5
  }
}

df = pd.DataFrame(data)

print(df)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0
# 5        60    102       127     300.5

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password=""
)

mycursor = mydb.cursor()

mycursor.execute("CREATE DATABASE mydatabase")

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password=""
)

mycursor = mydb.cursor()

mycursor.execute("SHOW DATABASES")

for x in mycursor:
  print(x)
# Out:
# ('information_schema',)
# ('mydatabase',)
# ('mysql',)
# ('performance_schema',)
# ('phpmyadmin',)
# ('satan',)
# ('test',)

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="",
  database="mydatabase"
)

mycursor = mydb.cursor()

mycursor.execute("CREATE TABLE customers (name VARCHAR(255), address VARCHAR(255))")

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="",
  database="mydatabase"
)

mycursor = mydb.cursor()

mycursor.execute("SHOW TABLES")

for x in mycursor:
     print(x)
# Out:
# ('customers',)

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="",
  database="mydatabase"
)

mycursor = mydb.cursor()

sql = "INSERT INTO customers (name, address) VALUES (%s, %s)"
val = ("John", "Highway 21")

mycursor.execute(sql, val)

mydb.commit()

print(mycursor.rowcount, "record inserted.")
# Out:
# 1 record inserted.

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="",
  database="mydatabase"
)

mycursor = mydb.cursor()

sql = "DELETE FROM customers WHERE address = 'Highway 21'"

mycursor.execute(sql)

mydb.commit()

print(mycursor.rowcount, "record(s) deleted")
# Out:
# 1 record(s) deleted

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="",
  database="mydatabase"
)

mycursor = mydb.cursor()

sql = "DROP TABLE customers"

mycursor.execute(sql)
